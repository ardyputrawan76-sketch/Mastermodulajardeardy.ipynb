# %% [markdown]
# <a href="https://colab.research.google.com/github/ardyputrawan76-sketch/Mastermodulajardeardy.ipynb/blob/main/mastermodulajardeardy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# @title 📄 KODE BAGIAN 1 REVISI: MODUL UTAMA KELAS 5 (NARASI SUPER TEBAL & PADAT)
# ==============================================================================
# !pip install -q python-docx
import docx
from docx.shared import Pt, RGBColor
from google.colab import files

doc1 = docx.Document()

# Pengaturan Font Global agar Rapi dan Formal
style = doc1.styles['Normal']
font = style.font
font.name = 'Arial'
font.size = Pt(11)

def add_heading_styled(text, level):
    h = doc1.add_heading(text, level=level)
    h.paragraph_format.space_before = Pt(14)
    h.paragraph_format.space_after = Pt(6)
    h.paragraph_format.keep_with_next = True
    for run in h.runs:
        run.font.name = 'Arial'
        run.font.bold = True
        run.font.color.rgb = RGBColor(26, 54, 93) if level==1 else RGBColor(43, 108, 176)
    return h

# --- JUDUL UTAMA MODUL ---
p_title = doc1.add_paragraph()
p_title.alignment = docx.enum.text.WD_ALIGN_PARAGRAPH.CENTER
r_title = p_title.add_run("MODUL AJAR KURIKULUM MERDEKA BELAJAR (FASE C KELAS V)\n"
                          "BAB AKTIVITAS KETANGKASAN SENAM LANTAI SECARA LENGKAP DAN NARATIF\n"
                          "SD NEGERI 8 BANJAR ANYAR - TAHUN PELAJARAN 2026/2027")
r_title.font.size = Pt(14)
r_title.font.bold = True

add_heading_styled("I. INFORMASI UMUM PERANGKAT AJAR", level=1)
t_info = doc1.add_table(rows=5, cols=2)
t_info.style = 'Table Grid'
info = [
    ("Nama Penyusun / Guru Utama", "Gede Ardy Putrawan, S.Pd."),
    ("Guru Pendamping / Mitra Lapangan", "Guru PJOK Mitra Kelas V"),
    ("Target Sasaran / Alokasi Waktu", "60 Murid Gabungan Paralel / 1 Pertemuan (2 x 35 Menit)"),
    ("Materi Pokok / Bahasan", "Kombinasi Pola Gerak Dominan Ketangkasan: Guling Depan (Forward Roll) dan Sikap Lilin"),
    ("Payung Hukum Aturan Proses", "Prinsip Pembelajaran Mindful, Meaningful, & Joyful (Permendikdasmen No. 1 Tahun 2026)")
]
for i, (k, v) in enumerate(info):
    t_info.rows[i].cells[0].text = k
    t_info.rows[i].cells[1].text = v
    t_info.rows[i].cells[0].paragraphs[0].runs[0].font.bold = True

add_heading_styled("A. Kompetensi Awal (Prasyarat Motorik Murid)", level=2)
doc1.add_paragraph(
    "Sebelum memasuki materi kombinasi pada Fase C, peserta didik diidentifikasi secara menyeluruh telah menguasai pola "
    "gerak dominan statis dasar dari pembelajaran di Fase A dan Fase B. Kemampuan prasyarat tersebut meliputi kekuatan "
    "menumpu menggunakan kedua telapak tangan secara kokoh, kelenturan persendian bahu, serta fleksibilitas otot punggung. "
    "Pada tingkat Kelas V ini, murid ditantang untuk mengintegrasikan seluruh kemampuan statis tersebut ke dalam sebuah "
    "rangkaian gerak dinamis tingkat lanjut. Aktivitas ini membutuhkan koordinasi motorik tinggi, regulasi mental untuk "
    "mengatasi kecemasan, kontrol biomekanika panggul saat memindahkan berat tubuh, serta kesadaran kinematik tinggi "
    "terhadap perlindungan area leher belakang."
)

add_heading_styled("B. Profil Pelajar Pancasila (Dimensi dan Indikator Perilaku)", level=2)
doc1.add_paragraph(
    "1. Mandiri: Murid mampu membangun regulasi emosi secara mandiri, mengatasi rasa cemas, ragu-ragu, atau takut saat "
    "melakukan putaran badan terbalik (guling depan) di atas matras, serta mampu menilai batasan kapasitas fisik diri sendiri secara jujur.\n"
    "2. Gotong Royong: Murid menunjukkan rasa empati yang mendalam serta tanggung jawab sosial yang tinggi ketika bertindak "
    "sebagai pemandu keselamatan (spotter). Mereka siaga menjaga, menopang, dan melindungi tubuh rekan sejawatnya dari risiko cedera jatuh.\n"
    "3. Bernalar Kritis: Murid tidak sekadar meniru gerakan, melainkan mampu memproses informasi postural, menganalisis sudut "
    "tolakan kaki, mengoreksi posisi dagu terhadap dada, serta mengevaluasi letak titik tumpu tangan untuk memperbaiki kegagalan gerak secara mandiri."
)

add_heading_styled("C. Sarana, Prasarana, dan Manajemen Keamanan Kelas Kolosal", level=2)
doc1.add_paragraph(
    "Mengingat jumlah peserta didik yang sangat masif dan padat (60 anak), manajemen sarana dan pengaturan ruang lapangan terbuka "
    "diatur secara ketat dengan rasio utilitas tinggi guna memastikan kondisi zero-accident selama sesi praktik berlangsung:\n"
    "1. Matras Senam Busa Padat (Minimal 6-8 Unit): Dijejerkan secara horizontal-paralel dengan jarak aman antar-matras minimal 2.5 meter sebagai zona steril dari benturan luar.\n"
    "2. Cone Marker / Kerucut Pembatas (12 Buah): Ditempatkan sebagai batas penanda antrean belakang bagi kelompok murid pengamat agar tidak menumpuk di sekitar area matras aktif.\n"
    "3. Megaphone Portable & Peluit Isyarat: Alat wajib bagi Guru Gede Ardy Putrawan untuk memastikan artikulasi instruksi terdengar jelas menembus ruang lapangan terbuka."
)

add_heading_styled("II. PROSEDUR DAN ALUR DETAIL KEGIATAN INTI LAPANGAN", level=1)

add_heading_styled("A. Kegiatan Pendahuluan (15 Menit) - Pengondisian & Apersepsi", level=2)
doc1.add_paragraph(
    "1. Pengondisian Kelas Kolosal: Guru Gede Ardy Putrawan meniup peluit dengan nada tegas ganda. Bersama Guru Mitra, "
    "mereka mengorganisir 60 siswa menjadi format setengah lingkaran besar menghadap ke arah barisan matras. Guru menyapa murid "
    "dengan penuh energi, menunjuk salah satu murid untuk memimpin doa keselamatan, dan memastikan seluruh murid mengenakan "
    "seragam olahraga standar tanpa menyisakan benda tajam (seperti pin, sabuk, atau jam tangan) yang berisiko mencederai fisik atau merusak matras.\n"
    "2. Pemeriksaan Fisik dan Apersepsi: Guru Mitra melakukan pengecekan kesehatan umum. Guru Gede Ardy memberikan apersepsi "
    "eksploratif dengan melemparkan pertanyaan pemantik: 'Anak-anak, mengapa roda yang berbentuk bulat bisa berputar sangat lancar? "
    "Bagaimana jika tubuh kita saat berguling ditekuk bulat seperti roda?'\n"
    "3. Pemanasan Joyful (Katak dan Elang): Murid melakukan lompat rendah dinamis (katak) mengikuti peluit tunggal, lalu saat peluit "
    "ganda ditiup murid harus berhenti tegak lurus menahan keseimbangan dengan tangan terbuka (elang). Aktivitas ini dirancang menyenangkan "
    "sekaligus merangsang kontraksi awal otot perut (core muscles) sebelum memasuki gerakan inti."
)

add_heading_styled("B. Kegiatan Inti (45 Menit) - Sintaks PBL & Manajemen 3-Layer", level=2)
doc1.add_paragraph(
    "Sistem Pembagian Kelompok: Kelas dipecah menjadi 6 kelompok mandiri (Kelompok A sampai F, masing-masing berisi 10 murid). "
    "Setiap kelompok menempati 1 unit matras yang ditandai dengan cone pembatas. Guru Gede Ardy mengawasi Pos 1, 2, dan 3 "
    "(Fokus kombinasi guling depan), sedangkan Guru Mitra mengawasi Pos 4, 5, dan 6 (Fokus penguatan sikap lilin)."
)
doc1.add_paragraph(
    "1. Sintaks 1: Orientasi Murid pada Masalah\n"
    "Guru Gede Ardy mendemonstrasikan dua model gerakan biomekanika di depan barisan. Model A: Berguling dengan posisi kepala tegak "
    "sehingga ubun-ubun menyentuh matras (akibatnya putaran macet dan leher terasa tertekan sakit). Model B: Berguling dengan "
    "menundukkan kepala dalam-dalam hingga dagu mengunci rapat di dada, daratan bertumpu pada tengkuk leher belakang (akibatnya putaran "
    "berjalan bulat, mulus, dan aman). Murid diminta menalar secara kritis rahasia mekanika di balik keberhasilan Model B.\n\n"
    "2. Sintaks 2: Mengorganisasikan Murid untuk Belajar (Manajemen 3-Layer)\n"
    "Untuk mengantisipasi antrean panjang dari 60 siswa, diterapkan pembagian peran berlapis di setiap pos matras kelompok. "
    "Setiap 5 menit guru meniup peluit panjang penanda rotasi peran internal kelompok:\n"
    "   * LAYER 1 (Praktikan - 2 Siswa): Bertindak selaku pelaku gerakan aktif yang mempraktikkan rangkaian kombinasi di atas matras.\n"
    "   * LAYER 2 (Spotter / Penjaga - 2 Siswa): Berdiri siaga di sisi kanan dan kiri matras, bertugas memegang pinggang atau paha "
    "praktikan jika putaran badan macet di tengah jalan demi memitigasi risiko cedera leher.\n"
    "   * LAYER 3 (Evaluator LKPD - 6 Siswa): Berdiri tertib di belakang garis cone pembatas, mengamati teknik rekan yang praktik "
    "menggunakan checklist lembar kerja gambar visual.\n\n"
    "3. Sintaks 3: Membimbing Penyelidikan Individu dan Kelompok (Prosedur Mekanika Gerak)\n"
    "   - Prosedur Gerak Guling Depan (Forward Roll):\n"
    "     Siswa mengambil posisi awal jongkok rapat di ujung matras, letakkan kedua telapak tangan menapak penuh di atas permukaan "
    "matras selebar bahu. Angkat panggul ke atas, tekuk kedua siku lengan, masukkan kepala ke dalam di antara kedua lengan hingga "
    "dagu menempel rapat mengunci di dada. Tolakkan kedua kaki kuat-kuat, daratkan tengkuk (leher bagian belakang) terlebih dahulu "
    "di matras, biarkan badan berguling melingkar. Saat lutut lewat di depan muka, kedua tangan langsung memeluk lutut untuk kembali ke posisi jongkok tegak.\n"
    "   - Prosedur Gerak Sikap Lilin (Candlestick):\n"
    "     Dari posisi akhir pendaratan guling depan, siswa langsung mengambil posisi tidur telentang lurus. Angkat kedua kaki secara "
    "bersamaan lurus menuju garis vertikal tegak lurus. Secara instan, angkat panggul dari matras dan topang menggunakan kedua telapak "
    "tangan di otot pinggang belakang. Siku lengan bertindak sebagai tiang penopang kokoh di atas matras. Jaga ujung jari kaki tetap "
    "menunjuk lurus ke langit dan tahan kestabilan posisi diam ini selama minimal 8 hitungan penuh.\n\n"
    "4. Sintaks 4 & 5: Menyajikan Karya & Analisis Evaluasi\n"
    "Perwakilan kelompok memamerkan transisi kombinasi gerakan terbaik di matras pusat. Guru Gede Ardy memberikan umpan balik korektif: "
    "'Rahasia rotasi yang mulus ada pada tekukan dagu yang mengunci dada. Semakin bulat tubuh kita, semakin kecil hambatan putarannya.'"
)

add_heading_styled("C. Kegiatan Penutup (10 Menit) - Rileksasi & Tindak Lanjut", level=2)
doc1.add_paragraph(
    "1. Pendinginan (Cooling Down): Siswa duduk santai format selonjor berpasangan. Melakukan pijat punggung ringan berirama "
    "secara bergantian untuk merilekskan ketegangan otot erector spinae dan otot perut pasca-latihan.\n"
    "2. Refleksi Perilaku: Guru mengevaluasi aspek afektif kelas, memberikan apresiasi tinggi terhadap budaya mengantre tertib "
    "60 anak tanpa ada tindakan dorong-mendorong. Ketua kelompok mengumpulkan berkas administrasi LKPD kelompok, kelas ditutup dengan doa bersama, "
    "dan murid bergotong-royong merapikan kembali matras ke gudang olahraga."
)

doc1.add_page_break()

# ------------------------------------------------------------------------------
# III. SISTEM ASESMEN DAN RUBRIK PENILAIAN KINERJA (REVISI POSISI)
# ------------------------------------------------------------------------------
add_heading_styled("III. SISTEM ASESMEN DAN RUBRIK PENILAIAN KINERJA", level=1)
doc1.add_paragraph("Tabel Kriteria Ketercapaian Tujuan Pembelajaran (KKTP) Aspek Psikomotorik:")

table_perf = doc1.add_table(rows=3, cols=4)
table_perf.style = 'Table Grid'
perf_headers = ["Kriteria / Indikator Gerak", "Kategori Mahir (Skor 4)", "Kategori Layak (Skor 3)", "Baru Berkembang (Skor 1-2)"]
for j, txt in enumerate(perf_headers):
    table_perf.rows[0].cells[j].text = txt
    table_perf.rows[0].cells[j].paragraphs[0].runs[0].font.bold = True

# Data Rubrik Penilaian
table_perf.rows[1].cells[0].text = "Mekanika Guling Depan"
table_perf.rows[1].cells[1].text = "Tumpuan tangan kokoh, dagu mengunci di dada, rotasi mulus bertumpu pada tengkuk, kembali ke posisi jongkok tegak tanpa bantuan."
table_perf.rows[1].cells[2].text = "Tumpuan tangan baik, namun pendaratan akhir agak condong ke samping atau memerlukan bantuan tangan saat kembali jongkok."
table_perf.rows[1].cells[3].text = "Ubun-ubun kepala menyentuh matras saat berguling, putaran macet di tengah jalan, atau jatuh telentang."

table_perf.rows[2].cells[0].text = "Stabilitas Sikap Lilin"
table_perf.rows[2].cells[1].text = "Kaki lurus vertikal ke atas, pinggang ditopang penuh oleh tangan, posisi tegak lurus konstan tanpa goyang >8 detik."
table_perf.rows[2].cells[2].text = "Kaki terangkat ke atas namun lutut agak menekuk, pinggang ditopang, mampu bertahan selama 4-7 detik."
table_perf.rows[2].cells[3].text = "Gagal mengangkat panggul dari matras, posisi kaki miring atau roboh sebelum hitungan ke-3."

# ==============================================================================
# LEMBAR TANDA TANGAN VALIDASI (DI DEPAN/DI BAWAH TABEL PENILAIAN PERSIS)
# ==============================================================================
doc1.add_paragraph("\n\n")
table_sig = doc1.add_table(rows=1, cols=2)
table_sig.autofit = False

cell_left = table_sig.rows[0].cells[0]
cell_right = table_sig.rows[0].cells[1]

p_left = cell_left.paragraphs[0]
p_left.text = f"Mengetahui,\nKepala {NAMA_SEKOLAH}\n\n\n\n___________________________\nNIP. "

p_right = cell_right.paragraphs[0]
p_right.text = f"Banjar Anyar, Mei 2026\nGuru Mata Pelajaran PJOK,\n\n\n\n{NAMA_GURU_UTAMA}\nNIP. -"

# Simpan Dokumen
doc1.save("1_Modul_Utama_Senam_Lantai_Kelas5_Tebal_Revisi.docx")
files.download("1_Modul_Utama_Senam_Lantai_Kelas5_Tebal_Revisi.docx")
print("\n[BERHASIL] File '1_Modul_Utama_Senam_Lantai_Kelas5_Tebal_Revisi.docx' versi super tebal dengan TTD di bawah penilaian telah diunduh!")
# Out:
# [BERHASIL] File '1_Modul_Utama_Senam_Lantai_Kelas5_Tebal_Revisi.docx' versi super tebal dengan TTD di bawah penilaian telah diunduh!

# %%
# ==============================================================================
# @title 📝 KODE REVISI BAGIAN 2: INSTRUMEN LKPD & BANK SOAL HOTS KELAS 5 (TEBAL)
# ==============================================================================
# !pip install -q python-docx
import docx
from docx.shared import Pt, RGBColor
from google.colab import files

doc2 = docx.Document()
style = doc2.styles['Normal']; font = style.font; font.name = 'Arial'; font.size = Pt(11)

def add_heading_styled(text, level):
    h = doc2.add_heading(text, level=level)
    h.paragraph_format.space_before = Pt(14); h.paragraph_format.space_after = Pt(6)
    for run in h.runs:
        run.font.name = 'Arial'; run.font.bold = True
        run.font.color.rgb = RGBColor(26, 54, 93) if level==1 else RGBColor(43, 108, 176)
    return h

add_heading_styled("III. LEMBAR KERJA PESERTA DIDIK (LKPD) KELOMPOK KINESTETIK LAPANGAN", level=1)
p_meta = doc2.add_paragraph()
p_meta.add_run("Nama Kelompok  : ____________________\n"
               "Satuan Pendidikan : SD Negeri 8 Banjar Anyar\n"
               "Anggota Kelompok  : (Tuliskan nama lengkap 10 murid beserta layer perannya)\n"
               "1. __________________  2. __________________  3. __________________\n"
               "4. __________________  5. __________________  6. __________________\n"
               "7. __________________  8. __________________  9. __________________\n"
               "10. _________________\n"
               "Guru Pengampu : Gede Ardy Putrawan, S.Pd.").font.italic = True

add_heading_styled("A. Panduan Kerja Dan Mekanisme Penilaian Antar-Teman (Peer-Assessment)", level=2)
doc2.add_paragraph(
    "1. Setiap kelompok wajib memegang satu berkas LKPD ini di area pos matras masing-masing.\n"
    "2. Lakukan pembagian peran secara adil sesuai instruksi Guru Gede Ardy: 2 orang bertindak sebagai Praktikan gerak, "
    "2 orang bertindak sebagai Spotter (Penjaga Keselamatan) di sisi matras, dan 6 orang berdiri tertib di belakang cone penanda sebagai Tim Evaluator.\n"
    "3. Ketika temanmu melakukan rangkaian gerakan, amati kesesuaian biomekanikanya secara jeli, lalu berikan tanda centang (✓) pada kolom 'Ya' atau 'Tidak' di tabel observasi bawah ini.\n"
    "4. Lakukan rotasi peran searah jarum jam setiap kali terdengar suara peluit panjang dari guru."
)

# Tabel Observasi Detail
table = doc2.add_table(rows=11, cols=5); table.style = 'Table Grid'
headers = ["No", "Nama Siswa Praktikan", "Guling Depan: Tengkuk Menyentuh Matras Dulu? (Ya/Tidak)", "Guling Depan: Sikap Akhir Jongkok Tegak? (Ya/Tidak)", "Sikap Lilin: Panggul Lurus Disangga Tangan >8 Detik? (Ya/Tidak)"]
for j, txt in enumerate(headers):
    table.rows[0].cells[j].text = txt
    table.rows[0].cells[j].paragraphs[0].runs[0].font.bold = True

for i in range(1, 11):
    table.rows[i].cells[0].text = str(i)

add_heading_styled("B. Lembar Diskusi Masalah Biomekanika Olahraga (Penalaran Kritis)", level=2)
doc2.add_paragraph(
    "Pertanyaan Kasus 1:\n"
    "Ketika anggota kelompokmu melakukan gerakan Guling Depan, mengapa ada beberapa anak yang arah putaran badannya selalu melenceng miring keluar dari matras atau putarannya terhenti (macet) di tengah-tengah punggung? Analisis bersama kelompokmu mengenai posisi telapak tangan dan distribusi gaya tumpuannya!\n"
    "Jawaban Analisis Kelompok:\n___________________________________________________________________________________________________\n"
    "___________________________________________________________________________________________________\n\n"
    "Pertanyaan Kasus 2:\n"
    "Pada gerakan Sikap Lilin, mengapa posisi panggul dan pinggang belakang wajib disangga dengan kuat menggunakan kedua telapak tangan? Apa akibat kinematik yang terjadi jika praktikan melepaskan tumpuan tangannya sebelum hitungan ke-8 selesai?\n"
    "Jawaban Analisis Kelompok:\n___________________________________________________________________________________________________\n"
    "___________________________________________________________________________________________________"
)

add_heading_styled("IV. BANK SOAL EVALUASI PENGETAHUAN BERBASIS HOTS (C4 - C6)", level=1)
doc2.add_paragraph("Petunjuk Pengerjaan: Bacalah ilustrasi kasus di bawah ini dengan cermat, lalu pilih satu jawaban yang paling tepat dan logis!")

p1 = doc2.add_paragraph()
p1.add_run("1. Saat melakukan kombinasi gerakan guling depan, Made mengalami kegagalan di mana arah putaran badannya selalu miring dan jatuh ke sisi kanan matras. Setelah dianalisis oleh Guru Gede Ardy, posisi awal Made sudah lurus. Berdasarkan prinsip biomekanika senam lantai, apa penyebab utama kegagalan gerakan Made?").font.bold = True
doc2.add_paragraph("A. Made menolak menggunakan kedua ujung jari kakinya dengan terlalu kuat.\n"
                   "B. Kekuatan tekanan telapak tangan kiri pada matras lebih lemah atau terlepas lebih cepat daripada tangan kanan.\n"
                   "C. Posisi dagu Made terlalu rapat menempel di dadanya saat melakukan putaran.\n"
                   "D. Matras yang digunakan terlalu tebal sehingga menghambat laju putaran tubuh.")

p2 = doc2.add_paragraph()
p2.add_run("2. Mengapa bentuk tubuh yang membulat (lutut ditekuk rapat ke dada dan kepala ditundukkan dalam-dalam) sangat krusial dalam pelaksanaan guling depan? Hubungkan analisis Anda dengan hukum kecepatan sudut putaran tubuh!").font.bold = True
doc2.add_paragraph("A. Tubuh yang membulat meningkatkan luas permukaan sentuh dengan matras agar tidak terpeleset.\n"
                   "B. Bentuk membulat memperkecil jarak poros gerak dengan pusat massa tubuh sehingga momentum rotasi berjalan lebih cepat, mulus, dan bertenaga.\n"
                   "C. Menjaga agar otot perut tidak mengalami kontraksi berlebih saat berputar di atas lantai.\n"
                   "D. Mengurangi tekanan udara di sekitar area lapangan SD Negeri 8 Banjar Anyar.")

p3 = doc2.add_paragraph()
p3.add_run("3. [Soal Esai Analisis Masalah Keamanan / Spotting]\n"
           "Bayangkan Anda sedang ditugaskan menjadi seorang 'Spotter' (Penjaga Keselamatan) di samping matras. Ketika teman Anda melakukan guling depan, di tengah-tengah gerakan badannya berhenti mendadak (macet) dalam posisi punggung menempel di matras dan kedua kaki menggantung tegak di atas wajahnya. Uraikan tindakan darurat fisik apa yang harus Anda lakukan secara instan sebagai spotter untuk membantu teman Anda menyelesaikan putarannya dengan selamat tanpa menimbulkan cedera otot leher!").font.bold = True
doc2.add_paragraph("Jawaban Analisis Mandiri Siswa:\n___________________________________________________________________________________________________\n"
                   "___________________________________________________________________________________________________\n"
                   "___________________________________________________________________________________________________")

# --- KUNCI JAWABAN DAN PEDOMAN PENSKORAN ---
add_heading_styled("C. Kunci Jawaban Dan Pedoman Penskoran", level=2)
doc2.add_paragraph(
    "Kunci Pilihan Ganda:\n"
    "1. B (Tekanan tangan tidak seimbang membuat distribusi gaya dorong berat sebelah, sehingga arah gulingan melenceng ke sisi yang lemah).\n"
    "2. B (Hukum momentum sudut: memperkecil radius tubuh akan melipatgandakan kecepatan rotasi putaran).\n\n"
    "Pedoman Penskoran Esai:\n"
    "- Skor 5: Jawaban runtut, menggunakan analisis mekanika olahraga, memberikan solusi keselamatan logis.\n"
    "- Skor 1-3: Jawaban benar namun alasan kurang mendalam secara biomekanika gerak."
)

# ==============================================================================
# LEMBAR TANDA TANGAN VALIDASI (DI PALING BAWAH PERSIS)
# ==============================================================================
doc2.add_paragraph("\n\n")
table_sig = doc2.add_table(rows=1, cols=2); table_sig.autofit = False
cell_left = table_sig.rows[0].cells[0] ; cell_right = table_sig.rows[0].cells[1]
cell_left.paragraphs[0].text = "Mengetahui,\nKepala SD Negeri 8 Banjar Anyar\n\n\n\n___________________________\nNIP. "
cell_right.paragraphs[0].text = "Banjar Anyar, Mei 2026\nGuru Mata Pelajaran PJOK,\n\n\n\nGede Ardy Putrawan, S.Pd.\nNIP. -"

doc2.save("2_Lampiran_LKPD_dan_Soal_HOTS_Kelas5_Tebal.docx")
files.download("2_Lampiran_LKPD_dan_Soal_HOTS_Kelas5_Tebal.docx")
print("Bagian 2 Selesai Direvisi & Terunduh!")
# Out:
# Bagian 2 Selesai Direvisi & Terunduh!

# %%
# ==============================================================================
# @title 🛠️ KODE REVISI BAGIAN 3: ASESMEN DIAGNOSTIK, REMEDIAL & GLOSARIUM KELAS 5 (TEBAL)
# ==============================================================================
# !pip install -q python-docx
import docx
from docx.shared import Pt, RGBColor
from google.colab import files

doc3 = docx.Document()
style = doc3.styles['Normal']; font = style.font; font.name = 'Arial'; font.size = Pt(11)

def add_heading_styled(text, level):
    h = doc3.add_heading(text, level=level)
    h.paragraph_format.space_before = Pt(14); h.paragraph_format.space_after = Pt(6)
    for run in h.runs:
        run.font.name = 'Arial'; run.font.bold = True
        run.font.color.rgb = RGBColor(26, 54, 93) if level==1 else RGBColor(43, 108, 176)
    return h

add_heading_styled("V. INSTRUMEN ASESMEN DIAGNOSTIK MEDIS JALUR DIFERENSIASI", level=1)
doc3.add_paragraph(
    "Sebelum aktivitas praktik fisik dimulai, Guru Utama (Gede Ardy Putrawan) dan Guru Mitra wajib melakukan "
    "skrining kesehatan awal pada seluruh 60 murid. Hal ini bertujuan untuk memetakan kondisi fisik aktual murid, "
    "mencegah terjadinya cedera kambuhan, serta menerapkan prinsip pembelajaran berdiferensiasi (Diferensiasi Proses) "
    "sesuai amanat Kurikulum Merdeka:"
)

# Tabel Asesmen Medis Lapangan
t_diag = doc3.add_table(rows=4, cols=3); t_diag.style = 'Table Grid'
headers = ["Kategori Kondisi Fisik Aktual Murid", "Jumlah Temuan", "Modifikasi Instruksi Pelayanan & Tindakan Spesifik Guru"]
for j, txt in enumerate(headers):
    t_diag.rows[0].cells[j].text = txt
    t_diag.rows[0].cells[j].paragraphs[0].runs[0].font.bold = True

diag_data = [
    ("Kondisi Prima / Bugar Total", "_____ Anak", "Mengikuti seluruh rangkaian kegiatan praktik kombinasi senam (pos guling depan & sikap lilin) secara penuh dengan sistem 3-layer kelompok."),
    ("Riwayat Medis Khusus (Asma/Obesitas/Cedera Bawaan)", "_____ Anak", "Diberikan kompensasi pengurangan jumlah pengulangan gerakan (repetisi), tidak dipaksa mencapai posisi vertikal sempurna, dan ditopang/disangga secara ekstra oleh Guru Mitra."),
    ("Sedang Sakit / Pusing / Kurang Fit saat Presensi", "_____ Anak", "Dipindahkan dari zona matras aktif menuju Pos Aman Medis Lapangan. Murid dibebaskan dari praktik gerakan fisik, namun tetap aktif bertindak selaku Evaluator Pencatat checklist LKPD kelompok.")
]
for i, r_data in enumerate(diag_data):
    for j, val in enumerate(r_data): t_diag.rows[i+1].cells[j].text = val

add_heading_styled("VI. PROGRAM TINDAK LANJUT (REMEDIAL DAN PENGAYAAN FORMAL)", level=1)
doc3.add_paragraph(
    "A. PROGRAM REMEDIAL (Bimbingan Khusus Pasca-Asesmen)\n"
    "Diberikan kepada peserta didik yang belum mencapai Kriteria Ketercapaian Tujuan Pembelajaran (KKTP) setelah evaluasi. "
    "Bentuk perlakuan berupa modifikasi media pembelajaran: Siswa melakukan gerakan guling depan di atas bidang matras miring "
    "(menggunakan bantuan gaya gravitasi untuk memudahkan rotasi tubuh) dan mendapatkan panduan sentuhan fisik (*tactile guidance*) "
    "secara privat oleh Guru Mitra hingga posisi pendaratan jongkok tegaknya stabil.\n\n"
    "B. PROGRAM PENGAYAAN (Akselerasi Kompetensi Fisik)\n"
                  "Diberikan kepada peserta didik yang memiliki penguasaan motorik di atas rata-rata kelas (predikat Mahir). "
                  "Bentuk tantangan berupa peningkatan variasi kecepatan transisi (dari posisi pendaratan guling depan langsung mengambil posisi tidur untuk sikap lilin), "
                  "menambah durasi waktu penahanan postural keseimbangan hingga 15 detik, serta ditunjuk menjadi Kapten Tutor Sebaya yang bertanggung jawab memandu keselamatan rekan kelompoknya di pos."
)

add_heading_styled("VII. GLOSARIUM TEKNIS DAN DAFTAR PUSTAKA ACUAN LEGAL", level=1)
doc3.add_paragraph(
    "1. Pola Gerak Dominan (PGD): Induk atau fondasi utama dari seluruh rangkaian gerakan ketangkasan senam yang wajib dikuasai secara mekanis, meliputi bertumpu, keseimbangan, tolakan, dan putaran.\n"
    "2. Spotter: Istilah bagi asisten keselamatan (bisa murid pengamat atau guru pendamping) yang siaga di sisi matras untuk memberikan topangan fisik langsung pada pinggang praktikan guna mitigasi risiko cedera leher.\n"
    "3. Core Muscles (Otot Inti): Kelompok otot perut dan pinggang bagian dalam yang berfungsi sebagai poros utama dalam menstabilkan postur tubuh terbalik saat menahan posisi sikap lilin vertikal.\n"
    "4. Mindful, Meaningful & Joyful: Tiga pilar pengalaman belajar dalam regulasi Standar Proses baru yang menekankan kesadaran penuh gerakan, kebermaknaan fungsi hidup, serta penciptaan suasana belajar yang menggembirakan berpusat pada murid."
)
doc3.add_paragraph(
    "DAFTAR PUSTAKA:\n"
    "- Peraturan Menteri Pendidikan Dasar dan Menengah No. 1 Tahun 2026 tentang Standar Proses Baru Satuan Pendidikan.\n"
    "- Badan Standar, Kurikulum, dan Asesmen Pendidikan (BSKAP). (2024). Keputusan Kepala BSKAP No. 032/H/KR/2024 tentang Capaian Pembelajaran Kurdeka (Mata Pelajaran PJOK - Fase C).\n"
    "- Buku Panduan Guru Pendidikan Jasmani, Olahraga, dan Kesehatan Kelas V, Kemendikbudristek RI, Pusat Perbukuan BSKAP 2022."
)

# ==============================================================================
# LEMBAR TANDA TANGAN VALIDASI (DI PALING BAWAH PERSIS)
# ==============================================================================
doc3.add_paragraph("\n\n")
table_sig = doc3.add_table(rows=1, cols=2); table_sig.autofit = False
cell_left = table_sig.rows[0].cells[0] ; cell_right = table_sig.rows[0].cells[1]
cell_left.paragraphs[0].text = "Mengetahui,\nKepala SD Negeri 8 Banjar Anyar\n\n\n\n___________________________\nNIP. "
cell_right.paragraphs[0].text = "Banjar Anyar, Mei 2026\nGuru Mata Pelajaran PJOK,\n\n\n\nGede Ardy Putrawan, S.Pd.\nNIP. -"

doc3.save("3_Lampiran_Administrasi_Pelengkap_Kelas5_Tebal.docx")
files.download("3_Lampiran_Administrasi_Pelengkap_Kelas5_Tebal.docx")
print("Bagian 3 Selesai Direvisi & Terunduh!")
# Out:
# Bagian 3 Selesai Direvisi & Terunduh!
