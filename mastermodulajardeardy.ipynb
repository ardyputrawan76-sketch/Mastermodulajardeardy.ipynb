# %% [markdown]
# <a href="https://colab.research.google.com/github/ardyputrawan76-sketch/Mastermodulajardeardy.ipynb/blob/main/mastermodulajardeardy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# @title 📄 KODE BAGIAN 1 REVISI: MODUL UTAMA KELAS 5 (MATERI SEPAK BOLA)
# ==============================================================================
# !pip install -q python-docx

import docx
from docx.shared import Pt, RGBColor
from docx.enum.text import WD_ALIGN_PARAGRAPH
from google.colab import files

doc1 = docx.Document()

# Pengaturan Font Global agar Rapi dan Formal
style = doc1.styles['Normal']
font = style.font
font.name = 'Arial'
font.size = Pt(11)

def add_heading_styled(text, level):
    h = doc1.add_heading(text, level=level)
    h.paragraph_format.space_before = Pt(14)
    h.paragraph_format.space_after = Pt(6)
    h.paragraph_format.keep_with_next = True
    for run in h.runs:
        run.font.name = 'Arial'
        run.font.bold = True
        run.font.color.rgb = RGBColor(26, 54, 93) if level==1 else RGBColor(43, 108, 176)
    return h

# --- JUDUL UTAMA MODUL ---
p_title = doc1.add_paragraph()
p_title.alignment = WD_ALIGN_PARAGRAPH.CENTER
r_title = p_title.add_run(
    "MODUL_AJAR_KURIKULUM_MERDEKA_BELAJAR_(FASE_C_KELAS_V)\n"
    "BAB_1_PERMAINAN_INVASI:_SEPAK_BOLA_SECARA_LENGKAP_DAN_NARATIF\n"
    "SD_NEGERI_8_BANJAR_ANYAR_-_TAHUN_PELAJARAN_2026/2027"
)
r_title.font.size = Pt(14)
r_title.font.bold = True

add_heading_styled("I. INFORMASI UMUM PERANGKAT AJAR", level=1)

t_info = doc1.add_table(rows=5, cols=2)
t_info.style = 'Table Grid'

info = [
    ("Nama Penyusun / Guru Utama", "Gede Ardy Putrawan, S.Pd."),
    ("Guru Pendamping / Mitra Lapangan", "Guru PJOK Mitra Kelas V"),
    ("Target Sasaran / Alokasi Waktu", "60 Murid Gabungan Paralel / 1 Pertemuan (2 x 35 Menit)"),
    ("Materi Pokok / Bahasan", "Permainan Invasi: Kombinasi Pola Gerak Dasar Lokomotor, Non-lokomotor, dan Manipulatif dalam Menendang/Passing dan Menerima/Controlling Sepak Bola"),
    ("Payung Hukum Aturan Proses", "Prinsip Pembelajaran Mindful, Meaningful, & Joyful (Permendikdasmen No. 1 Tahun 2026)")
]

for i, (k, v) in enumerate(info):
    t_info.rows[i].cells[0].text = k
    t_info.rows[i].cells[1].text = v
    t_info.rows[i].cells[0].paragraphs[0].runs[0].font.bold = True

add_heading_styled("A. Kompetensi Awal (Prasyarat Motorik Murid)", level=2)
doc1.add_paragraph(
    "Sebelum memasuki materi kombinasi pada Fase C, peserta didik diidentifikasi secara menyeluruh telah "
    "menguasai pola gerak dasar dari pembelajaran di Fase A dan Fase B. Kemampuan prasyarat tersebut "
    "meliputi koordinasi ayunan kaki, keseimbangan tubuh saat menumpu satu kaki, serta kesadaran ruang. "
    "Pada tingkat Kelas V ini, murid ditantang untuk mengintegrasikan seluruh kemampuan statis tersebut ke dalam "
    "sebuah rangkaian gerak dinamis tingkat lanjut (passing dan menerima bola). Aktivitas ini membutuhkan "
    "koordinasi motorik tinggi, regulasi mental untuk mengatasi gangguan lawan, kontrol biomekanika pergelangan "
    "kaki saat mengenai bola, serta akurasi tinggi terhadap target operan."
)

add_heading_styled("B. Profil Pelajar Pancasila (Dimensi dan Indikator Perilaku)", level=2)
doc1.add_paragraph(
    "1. Mandiri: Murid mampu membangun regulasi emosi secara mandiri, mengontrol ego, dan mengambil keputusan cepat saat melakukan passing atau menerima bola di lapangan, serta mampu menilai batasan kapasitas fisik diri sendiri secara jujur.\n"
    "2. Gotong Royong: Murid menunjukkan rasa empati yang mendalam serta komunikasi tim yang tinggi ketika menyusun strategi operan. Mereka siaga bergerak membuka ruang, saling mendukung, dan membagi peran demi mencapai tujuan tim tanpa mendominasi bola sendirian.\n"
    "3. Bernalar Kritis: Murid tidak sekadar menendang bola asal jauh, melainkan mampu memproses informasi spasial, menganalisis sudut datangnya bola, mengoreksi posisi kaki tumpu, serta mengevaluasi perkenalan kaki pada bola untuk memperbaiki akurasi operan secara mandiri."
)

add_heading_styled("C. Sarana, Prasarana, dan Manajemen Keamanan Kelas Kolosal", level=2)
doc1.add_paragraph(
    "Mengingat jumlah peserta didik yang sangat masif dan padat (60 anak), manajemen sarana dan pengaturan ruang lapangan terbuka "
    "diatur secara ketat dengan rasio utilitas tinggi guna memastikan kondisi zero-accident selama sesi praktik berlangsung:\n"
    "1. Bola Sepak Ukuran 4 / Bola Spons Padat (Anak Pasif) (Minimal 6-8 Unit): Dibagikan ke setiap pos kelompok untuk memaksimalkan sentuhan bola per anak dan meminimalisir risiko cedera benturan keras.\n"
    "2. Cone Marker / Kerucut Pembatas (12 Buah): Ditempatkan sebagai batas koridor/lintasan passing bagi kelompok murid agar alur pergerakan bola teratur dan tidak saling bertabrakan antar kelompok.\n"
    "3. Megaphone Portable & Peluit Isyarat: Alat wajib bagi Guru Gede Ardy Putrawan untuk memastikan artikulasi instruksi operan dan rotasi terdengar jelas menembus ruang lapangan terbuka."
)

add_heading_styled("II. PROSEDUR DAN ALUR DETAIL KEGIATAN INTI LAPANGAN", level=1)

add_heading_styled("A. Kegiatan Pendahuluan (15 Menit) - Pengondisian & Apersepsi", level=2)
doc1.add_paragraph(
    "1. Pengondisian Kelas Kolosal: Guru Gede Ardy Putrawan meniup peluit dengan nada tegas ganda. Bersama Guru Mitra, "
    "mereka mengorganisir 60 siswa menjadi format setengah lingkaran besar menghadap ke arah area koridor passing. Guru menyapa murid "
    "dengan penuh energi, menunjuk salah salah satu murid untuk memimpin doa keselamatan, dan memastikan seluruh murid mengenakan "
    "seragam olahraga standar serta tali sepatu yang terikat kuat guna menghindari risiko terkilir.\n"
    "2. Pemeriksaan Fisik dan Apersepsi: Guru Mitra melakukan pengecekan kesehatan umum. Guru Gede Ardy memberikan apersepsi "
    "eksploratif dengan melemparkan pertanyaan pemantik: 'Anak-anak, jika kalian ingin mengirim pesan rahasia lewat tendangan bola agar tepat sampai di kaki teman, bagian kaki sebelah mana yang harus menyentuh bola? Bagaimana posisi kaki tumpu kalian agar bola tidak melambung liar?'\n"
    "3. Pemanasan Joyful (Kucing dan Tikus Operan): Murid melakukan permainan operan bola pendek dalam lingkaran kecil secara dinamis "
    "mengikuti tiupan peluit tunggal. Ketika peluit ganda ditiup, murid harus melakukan stop-ball dengan telapak kaki atau kaki bagian dalam. "
    "Aktivitas ini dirancang menyenangkan sekaligus merangsang kontraksi awal otot paha dan sendi pergelangan kaki sebelum memasuki gerakan inti."
)

add_heading_styled("B. Kegiatan Inti (45 Menit) - Sintaks PBL & Manajemen 3-Layer", level=2)
doc1.add_paragraph(
    "Sistem Pembagian Kelompok: Kelas dipecah menjadi 6 kelompok mandiri (Kelompok A sampai F, masing-masing berisi 10 murid). "
    "Setiap kelompok menempati 1 lintasan koridor passing yang ditandai dengan cone pembatas. Guru Gede Ardy mengawasi Pos 1, 2, dan 3 "
    "(Fokus mekanika kaki tumpu dan tendangan), sedangkan Guru Mitra mengawasi Pos 4, 5, dan 6 (Fokus akurasi dan kontrol/receiving bola)."
)

doc1.add_paragraph(
    "1. Sintaks 1: Orientasi Murid pada Masalah\n"
    "Guru Gede Ardy mendemonstrasikan dua model gerakan biomekanika di depan barisan. Model A: Menendang bola dengan posisi kaki tumpu terlalu jauh di belakang bola (akibatnya bola melambung ke atas tanpa arah dan rentan membuat keseimbangan hilang). Model B: Menendang bola dengan meletakkan kaki tumpu tepat di samping bola (jarak ±1 kepalan tangan), lutut sedikit ditekuk, dan bola ditendang tepat di tengah-tengahnya menggunakan kaki bagian dalam (akibatnya bola bergulir lurus, stabil, dan akurat). Murid diminta menalar secara kritis rahasia mekanika di balik keberhasilan Model B.\n\n"
    "2. Sintaks 2: Mengorganisasikan Murid untuk Belajar (Manajemen 3-Layer)\n"
    "Untuk mengantisipasi antrean panjang dari 60 siswa, diterapkan pembagian peran berlapis di setiap lintasan kelompok. "
    "Setiap 5 menit guru meniup peluit panjang penanda rotasi peran internal kelompok:\n"
    "   * LAYER 1 (Praktikan - 2 Siswa): Bertindak selaku pelaku gerakan aktif yang mempraktikkan rangkaian kombinasi passing dan kontrol bola secara berpasangan di dalam koridor.\n"
    "   * LAYER 2 (Spotter / Penjaga Lintasan - 2 Siswa): Berdiri siaga di sisi kanan dan kiri lintasan koridor, bertugas mengambil bola yang melenceng keluar jalur demi memitigasi risiko gangguan ke lintasan kelompok lain.\n"
    "   * LAYER 3 (Evaluator LKPD - 6 Siswa): Berdiri tertib di belakang garis cone pembatas, mengamati teknik rekan yang praktik menggunakan checklist lembar kerja akurasi operan.\n\n"
    "3. Sintaks 3: Membimbing Penyelidikan Individu dan Kelompok (Prosedur Mekanika Gerak)\n"
    "   - Prosedur Gerak Menendang Bola (Passing Kaki Dalam):\n"
    "     Siswa mengambil posisi awal berdiri di belakang bola. Tempatkan kaki tumpu di samping bola dengan jari kaki menghadap ke target operan. Ayunkan kaki tendang dari belakang ke depan dengan pergelangan kaki diputar ke luar dan dikunci rapat. Tendang bola tepat pada bagian tengahnya menggunakan permukaan kaki bagian dalam. Ikuti gerakan dengan melangkah maju (follow-through) untuk menjaga keseimbangan.\n"
    "   - Prosedur Gerak Menerima/Mengontrol Bola (Receiving):\n"
    "     Dari posisi siap menghadap arah datangnya bola, siswa menjemput bola secara rileks. Saat bola menyentuh kaki bagian dalam, tarik kaki sedikit ke belakang mengikuti arah laju bola (tindakan meredam momentum bola). Pastikan bola berhenti sempurna di dalam penguasaan (jarak dekat dari tubuh) dan siap untuk dioperkan kembali.\n\n"
    "4. Sintaks 4 & 5: Menyajikan Karya & Analisis Evaluasi\n"
    "Perwakilan kelompok memamerkan transisi kombinasi operan pendek satu-dua (one-two passing) terbaik di lapangan pusat. Guru Gede Ardy memberikan umpan balik korektif: 'Rahasia operan yang akurat ada pada posisi kaki tumpu di samping bola dan pergelangan kaki tendang yang dikunci. Semakin tenang tarikan kaki saat menerima, semakin jinak bolanya.'"
)

add_heading_styled("C. Kegiatan Penutup (10 Menit) - Rileksasi & Tindak Lanjut", level=2)
doc1.add_paragraph(
    "1. Pendinginan (Cooling Down): Siswa duduk santai format selonjor berpasangan. Melakukan ayunan kaki ringan dan saling meregangkan otot betis serta paha (hamstring) secara bergantian untuk merilekskan ketegangan pasca-latihan intensif.\n"
    "2. Refleksi Perilaku: Guru mengevaluasi aspek afektif kelas, memberikan apresiasi tinggi terhadap budaya kerja sama tim dan komunikasi yang baik antar 60 anak tanpa ada tindakan menyalahkan teman saat salah oper. Ketua kelompok mengumpulkan berkas administrasi LKPD kelompok, kelas ditutup dengan doa bersama, dan murid bergotong-royong merapikan kembali bola dan cone ke gudang olahraga."
)

doc1.add_page_break()

# ------------------------------------------------------------------------------
# III. SISTEM ASESMEN DAN RUBRIK PENILAIAN KINERJA
# ------------------------------------------------------------------------------
add_heading_styled("III. SISTEM ASESMEN DAN RUBRIK PENILAIAN KINERJA", level=1)
doc1.add_paragraph("Tabel Kriteria Ketercapaian Tujuan Pembelajaran (KKTP) Aspek Psikomotorik:")

table_perf = doc1.add_table(rows=3, cols=4)
table_perf.style = 'Table Grid'

perf_headers = ["Kriteria / Indikator Gerak", "Kategori Mahir (Skor 4)", "Kategori Layak (Skor 3)", "Baru Berkembang (Skor 1-2)"]
for j, txt in enumerate(perf_headers):
    table_perf.rows[0].cells[j].text = txt
    table_perf.rows[0].cells[j].paragraphs[0].runs[0].font.bold = True

# Data Rubrik Penilaian Sepak Bola
table_perf.rows[1].cells[0].text = "Mekanika Menendang Bola (Passing)"
table_perf.rows[1].cells[1].text = "Kaki tumpu tepat di samping bola, pergelangan kaki tendang dikunci ke luar, perkenaan bola pas di tengah kaki dalam, gerakan follow-through sempurna, bola akurat ke target."
table_perf.rows[1].cells[2].text = "Kaki tumpu baik, namun pergelangan kaki kurang dikunci sehingga arah bola kadang sedikit melenceng atau laju bola kurang bertenaga."
table_perf.rows[1].cells[3].text = "Posisi kaki tumpu terlalu jauh, menendang menggunakan ujung jari kaki, bola melambung liar atau melenceng jauh dari target."

table_perf.rows[2].cells[0].text = "Mekanika Mengontrol Bola (Receiving)"
table_perf.rows[2].cells[1].text = "Posisi tubuh siap menghadap bola, mampu menarik kaki ke belakang saat menyentuh bola untuk meredam momentum, bola berhenti sempurna di dekat kaki."
table_perf.rows[2].cells[2].text = "Mampu menghentikan bola menggunakan kaki bagian dalam, namun kaki statis (tidak ditarik ke belakang) sehingga bola agak memantul menjauh dari tubuh."
table_perf.rows[2].cells[3].text = "Gagal membaca arah datangnya bola, bola lolos di bawah kaki, atau bola memantul sangat jauh hingga direbut kelompok lain."

# ==============================================================================
# PENAMBAHAN RUMUS PENILAIAN (TTD DIHAPUS)
# ==============================================================================
add_heading_styled("Pengolahan Nilai Akhir Aspek Psikomotorik (Kinerja):", level=2)
doc1.add_paragraph(
    "Rumus Perhitungan Nilai:\n"
    "Nilai Akhir = (Total Skor yang Diperoleh / Total Skor Maksimal) x 100\n\n"
    "Keterangan:\n"
    "- Total Skor Maksimal = 8 (Jika mendapat skor 4 pada kedua indikator gerak).\n"
    "- Rentang Nilai Akhir:\n"
    "  * 86 - 100 : Kategori Mahir\n"
    "  * 71 - 85  : Kategori Layak\n"
    "  * 0 - 70   : Kategori Baru Berkembang"
)

# Simpan dan Download Otomatis
output_filename = "1_Modul_Utama_Sepak_Bola_Kelas5_Tebal_Revisi.docx"
doc1.save(output_filename)
files.download(output_filename)

print(f"\n[BERHASIL] File '{output_filename}' versi sepak bola telah ditambahkan rumus penilaian & TTD dihapus!")
# Out:
# [BERHASIL] File '1_Modul_Utama_Sepak_Bola_Kelas5_Tebal_Revisi.docx' versi sepak bola telah ditambahkan rumus penilaian & TTD dihapus!

# %%
# ==============================================================================
# @title 📝 KODE REVISI BAGIAN 2: INSTRUMEN LKPD & BANK SOAL HOTS KELAS 5 (SEPAK BOLA)
# ==============================================================================
# !pip install -q python-docx

import docx
from docx.shared import Pt, RGBColor
from google.colab import files

doc2 = docx.Document()

style = doc2.styles['Normal']
font = style.font
font.name = 'Arial'
font.size = Pt(11)

def add_heading_styled(text, level):
    h = doc2.add_heading(text, level=level)
    h.paragraph_format.space_before = Pt(14)
    h.paragraph_format.space_after = Pt(6)
    for run in h.runs:
        run.font.name = 'Arial'
        run.font.bold = True
        run.font.color.rgb = RGBColor(26, 54, 93) if level==1 else RGBColor(43, 108, 176)
    return h

add_heading_styled("III. LEMBAR KERJA PESERTA DIDIK (LKPD) KELOMPOK KINESTETIK LAPANGAN", level=1)

p_meta = doc2.add_paragraph()
p_meta.add_run(
    "Nama Kelompok   : ____________________\n"
    "Satuan Pendidikan : SD Negeri 8 Banjar Anyar\n"
    "Anggota Kelompok  : (Tuliskan nama lengkap 10 murid beserta layer perannya)\n"
    "1. __________________  2. __________________  3. __________________\n"
    "4. __________________  5. __________________  6. __________________\n"
    "7. __________________  8. __________________  9. __________________\n"
    "10. _________________\n"
    "Guru Pengampu : Gede Ardy Putrawan, S.Pd."
).font.italic = True

add_heading_styled("A. Panduan Kerja Dan Mekanisme Penilaian Antar-Teman (Peer-Assessment)", level=2)
doc2.add_paragraph(
    "1. Setiap kelompok wajib memegang satu berkas LKPD ini di area pos koridor masing-masing.\n"
    "2. Lakukan pembagian peran secara adil sesuai instruksi Guru Gede Ardy: 2 orang bertindak sebagai Praktikan gerak, "
    "2 orang bertindak sebagai Spotter (Penjaga Lintasan) di sisi koridor, dan 6 orang berdiri tertib di belakang cone penanda sebagai Tim Evaluator.\n"
    "3. Ketika temanmu melakukan rangkaian gerakan, amati kesesuaian biomekanikanya secara jeli, lalu berikan tanda centang (✓) pada kolom 'Ya' atau 'Tidak' di tabel observasi bawah ini.\n"
    "4. Lakukan rotasi peran searah jarum jam setiap kali terdengar suara peluit panjang dari guru."
)

# Tabel Observasi Detail Peer-Assessment
table = doc2.add_table(rows=11, cols=5)
table.style = 'Table Grid'

headers = [
    "No",
    "Nama Siswa Praktikan",
    "Passing: Kaki Tumpu di Samping Bola? (Ya/Tidak)",
    "Passing: Perkenaan Kaki Bagian Dalam Pas? (Ya/Tidak)",
    "Receiving: Bola Berhenti Sempurna & Tidak Memantul Jauh? (Ya/Tidak)"
]

for j, txt in enumerate(headers):
    table.rows[0].cells[j].text = txt
    table.rows[0].cells[j].paragraphs[0].runs[0].font.bold = True

for i in range(1, 11):
    table.rows[i].cells[0].text = str(i)

add_heading_styled("B. Lembar Diskusi Masalah Biomekanika Olahraga (Penalaran Kritis)", level=2)
doc2.add_paragraph(
    "Pertanyaan Kasus 1:\n"
    "Ketika anggota kelompokmu melakukan operan (passing) menggunakan kaki bagian dalam, mengapa ada beberapa anak yang laju bolanya selalu melambung tinggi ke atas atau arahnya miring keluar lintasan? Analisis bersama kelompokmu mengenai posisi kaki tumpu dan letak perkenaan kaki pada bola tersebut!\n"
    "Jawaban Analisis Kelompok:\n_________________________________________________________________________________________________\n"
    "_________________________________________________________________________________________________\n\n"
    "Pertanyaan Kasus 2:\n"
    "Pada teknik menerima/mengontrol bola datar yang melaju cepat, mengapa praktikan wajib menarik kaki bagian dalam sedikit ke belakang pada saat menyentuh bola? Hubungkan analisis kinetik kelompokmu dengan apa yang akan terjadi jika kaki praktikan ditahan kaku/keras tanpa ada gerakan penarikan mundur!\n"
    "Jawaban Analisis Kelompok:\n_________________________________________________________________________________________________\n"
    "_________________________________________________________________________________________________"
)

add_heading_styled("IV. BANK SOAL EVALUASI PENGETAHUAN BERBASIS HOTS (C4 - C6)", level=1)
doc2.add_paragraph("Petunjuk Pengerjaan: Bacalah ilustrasi kasus di bawah ini dengan cermat, lalu pilih satu jawaban yang paling tepat dan logis!")

p1 = doc2.add_paragraph()
p1.add_run(
    "1. Saat melakukan kombinasi operan sepak bola, lintasan bola yang ditendang oleh Edo selalu melambung tinggi ke atas sehingga sulit dikontrol oleh rekan satu timnya. Setelah dianalisis oleh Guru Gede Ardy, Edo sudah menendang menggunakan kaki bagian dalam. Berdasarkan prinsip biomekanika sepak bola, apa penyebab utama kegagalan teknik Edo?"
).font.bold = True
doc2.add_paragraph(
    "A. Kaki tendang Edo tidak diayunkan dari arah belakang tubuh.\n"
    "B. Posisi kaki tumpu Edo diletakkan terlalu jauh di belakang bola dan perkenaan tendangan berada di bawah bagian tengah bola.\n"
    "C. Edo mengunci pergelangan kaki tendangnya terlalu kuat saat mengenai bola.\n"
    "D. Bola yang digunakan memiliki tekanan udara yang terlalu rendah sehingga terlalu empuk."
)

p2 = doc2.add_paragraph()
p2.add_run(
    "2. Dalam sebuah pertandingan sepak bola modifikasi, tim Kelompok A ingin memberikan operan terobosan yang cepat namun tetap akurat menyusur tanah melewati penjagaan lawan. Mengapa kombinasi passing menggunakan kaki bagian dalam dengan posisi tubuh condong sedikit ke depan menjadi pilihan biomekanika yang paling rasional untuk strategi ini?"
).font.bold = True
doc2.add_paragraph(
    "A. Karena kaki bagian dalam memiliki permukaan yang luas sehingga meningkatkan area kontak untuk akurasi tinggi, dan posisi condong ke depan menekan pusat massa agar bola tidak melambung tinggi.\n"
    "B. Karena ujung sepatu dapat memberikan gaya dorong eksponensial yang tidak terduga oleh lawan.\n"
    "C. Mengurangi gesekan udara di lapangan SD Negeri 8 Banjar Anyar agar bola melaju tanpa hambatan.\n"
    "D. Memaksa otot perut berkontraksi statis agar pemain lawan merasa takut untuk merebut bola."
)

p3 = doc2.add_paragraph()
p3.add_run(
    "3. [Soal Esai Analisis Masalah Keamanan / Spotting]\n"
    "Bayangkan Anda sedang ditugaskan menjadi 'Spotter / Penjaga Lintasan' di sisi koridor permainan. Ketika rekan Anda bersiap menerima operan bola bawah yang melaju sangat kencang, tiba-tiba bola tersebut mengenai batu kecil di lapangan sehingga arahnya berbelok mendadak menuju ke arah wajah praktikan yang sedang tidak siap. Uraikan tindakan komunikatif dan fisik darurat apa yang harus Anda lakukan secara instan sebagai spotter untuk melindungi keselamatan rekan Anda tersebut!"
).font.bold = True
doc2.add_paragraph(
    "Jawaban Analisis Mandiri Siswa:\n_________________________________________________________________________________________________\n"
    "_________________________________________________________________________________________________\n"
    "_________________________________________________________________________________________________"
)

add_heading_styled("C. Kunci Jawaban Dan Pedoman Penskoran", level=2)
doc2.add_paragraph(
    "Kunci Pilihan Ganda:\n"
    "1. B (Kaki tumpu di belakang bola menyebabkan sudut datang kaki mengangkat bola ke atas, didukung perkenaan bawah bola yang menciptakan gaya angkat/lift).\n"
    "2. A (Hukum mekanika olahraga: area kontak yang lebih luas meminimalisir deviasi sudut kesalahan operan, kontrol postur condong ke depan menjaga bola tetap menyusur tanah/low drive).\n\n"
    "Pedoman Penskoran Esai:\n"
    "- Skor 5: Jawaban runtut, menggunakan analisis manajemen keselamatan lapangan, memberikan solusi tindakan fisik dan lisan yang instan dan logis.\n"
    "- Skor 1-3: Jawaban benar namun alasan tindakan kurang mendalam atau kurang relevan dengan mitigasi risiko cedera di lapangan."
)

# Simpan Dokumen Bagian 2
output_filename = "2_Instrumen_LKPD_HOTS_Sepak_Bola_Kelas5_Tebal.docx"
doc2.save(output_filename)
files.download(output_filename)

print(f"\n[BERHASIL] File '{output_filename}' versi sepak bola kelas 5 telah diunduh!")
# Out:
# [BERHASIL] File '2_Instrumen_LKPD_HOTS_Sepak_Bola_Kelas5_Tebal.docx' versi sepak bola kelas 5 telah diunduh!

# %%
# ==============================================================================
# @title 🛠️ KODE REVISI BAGIAN 3: ASESMEN DIAGNOSTIK, REMEDIAL & GLOSARIUM KELAS 5 (SEPAK BOLA)
# ==============================================================================
# !pip install -q python-docx

import docx
from docx.shared import Pt, RGBColor
from google.colab import files

doc3 = docx.Document()

style = doc3.styles['Normal']; font = style.font; font.name = 'Arial'; font.size = Pt(11)

def add_heading_styled(text, level):
    h = doc3.add_heading(text, level=level)
    h.paragraph_format.space_before = Pt(14); h.paragraph_format.space_after = Pt(6)
    for run in h.runs:
        run.font.name = 'Arial'; run.font.bold = True
        run.font.color.rgb = RGBColor(26, 54, 93) if level==1 else RGBColor(43, 108, 176)
    return h

add_heading_styled("V. INSTRUMEN ASESMEN DIAGNOSTIK MEDIS JALUR DIFERENSIASI", level=1)
doc3.add_paragraph(
    "Sebelum aktivitas praktik fisik dimulai, Guru Utama (Gede Ardy Putrawan) and Guru Mitra wajib melakukan "
    "skrining kesehatan awal pada seluruh 60 murid. Hal ini bertujuan untuk memetakan kondisi fisik aktual murid, "
    "mencegah terjadinya cedera kambuhan, serta menerapkan prinsip pembelajaran berdiferensiasi (Diferensiasi Proses) "
    "sesuai amanat Kurikulum Merdeka:"
)

# Tabel Asesmen Medis Lapangan Sepak Bola
t_diag = doc3.add_table(rows=4, cols=3); t_diag.style = 'Table Grid'
headers = ["Kategori Kondisi FIsik Aktual Murid", "Jumlah Temuan", "Modifikasi Instruksi Pelayanan & Tindakan Spesifik Guru"]
for j, txt in enumerate(headers):
    t_diag.rows[0].cells[j].text = txt
    t_diag.rows[0].cells[j].paragraphs[0].runs[0].font.bold = True

diag_data = [
    ("Kondisi Prima / Bugar Total", "_____ Anak", "Mengikuti seluruh rangkaian kegiatan praktik kombinasi permainan invasi (pos passing kaki dalam & receiving bola) secara penuh dengan sistem 3-layer kelompok."),
    ("Riwayat Medis Khusus (Asma/Obesitas/Cedera Bawaan)", "_____ Anak", "Diberikan kompensasi berupa pengurangan jarak koridor passing (misal dari 5 meter menjadi 3 meter), tidak dipaksa melakukan operan dengan power tinggi, dan intensitas pengawasan pergerakan kaki tumpu ditingkatkan oleh Guru Mitra."),
    ("Sedang Sakit / Pusing / Kurang Fit saat Presensi", "_____ Anak", "Dipindahkan dari area lintasan aktif menuju Pos Aman Medis Lapangan. Murid dibebaskan dari praktik menendang dan mengejar bola, namun tetap aktif bertindak selaku Evaluator Pencatat checklist LKPD kelompok di bangku teduh.")
]

for i, r_data in enumerate(diag_data):
    for j, val in enumerate(r_data):
        t_diag.rows[i+1].cells[j].text = val

add_heading_styled("VI. PROGRAM TINDAK LANJUT (REMEDIAL DAN PENGAYAAN FORMAL)", level=1)
doc3.add_paragraph(
    "A. PROGRAM REMEDIAL (Bimbingan Khusus Pasca-Asesmen)\n"
    "Diberikan kepada peserta didik yang belum mencapai Kriteria Ketercapaian Tujuan Pembelajaran (KKTP) setelah evaluasi. "
    "Bentuk perlakuan berupa modifikasi ukuran target operan: Siswa melakukan gerakan passing pendek menggunakan bola spons berukuran lebih besar ke arah gawang modifikasi yang lebar dengan jarak dekat, "
    "serta mendapatkan panduan sentuhan fisik (*tactile guidance*) pada posisi engsel pergelangan kaki oleh Guru Mitra hingga laju operannya lurus dan stabil.\n\n"
    "B. PROGRAM PENGAYAAN (Akselerasi Kompetensi Fisik)\n"
    "Diberikan kepada peserta didik yang memiliki penguasaan motorik di atas rata-rata kelas (predikat Mahir). "
    "Bentuk tantangan berupa peningkatan variasi kompleksitas: melakukan operan satu sentuhan langsung (one-touch passing) secara dinamis sambil bergerak maju-mundur, "
    "memperjauh jarak target operan hingga 10 meter, serta ditunjuk menjadi Kapten Tutor Sebaya yang bertanggung jawab memberikan umpan balik korektif kepada rekan kelompoknya di lintasan."
)

add_heading_styled("VII. GLOSARIUM TEKNIS DAN DAFTAR PUSTAKA ACUAN LEGAL", level=1)
doc3.add_paragraph(
    "1. Permainan Invasi: Jenis permainan olahraga di mana satu tim berusaha menyerang dan memasuki wilayah tim lawan untuk mencetak poin, sekaligus mempertahankan area sendiri dari serangan, contohnya sepak bola.\n"
    "2. Passing: Teknik dasar memindahkan atau mengoper bola dari satu pemain ke pemain lain dalam satu tim menggunakan kaki dengan target yang presisi.\n"
    "3. Receiving (Controlling): Teknik dasar menerima dan menghentikan bola yang datang agar bola berada di bawah kendali penuh sebelum melakukan tindakan lanjutan.\n"
    "4. Follow-through (Gerak Lanjutan): Gerakan melangkahkan kaki tendang ke depan sesaat setelah perkenaan kaki dengan bola untuk menjaga keseimbangan tubuh dan menyalurkan momentum gaya secara maksimal.\n"
    "5. Mindful, Meaningful & Joyful: Tiga pilar pengalaman belajar dalam regulasi Standar Proses baru yang menekankan kesadaran penuh gerakan, kebermaknaan fungsi hidup, serta penciptaan suasana belajar yang menggembirakan berpusat pada murid."
)

doc3.add_paragraph(
    "DAFTAR PUSTAKA:\n"
    "- Peraturan Menteri Pendidikan Dasar dan Menengah No. 1 Tahun 2026 tentang Standar Proses Baru Satuan Pendidikan.\n"
    "- Badan Standar, Kurikulum, dan Asesmen Pendidikan (BSKAP). (2024). Keputusan Kepala BSKAP No. 032/H/KR/2024 tentang Capaian Pembelajaran Kurikulum Merdeka (Mata Pelajaran PJOK - Fase C).\n"
    "- Buku Panduan Guru Pendidikan Jasmani, Olahraga, dan Kesehatan Kelas V, Kemendikbudristek RI, Pusat Perbukuan BSKAP 2022."
)

# ==============================================================================
# LEMBAR TANDA TANGAN VALIDASI (DI PALING BAWAH PERSIS)
# ==============================================================================
doc3.add_paragraph("\n\n")
table_sig = doc3.add_table(rows=1, cols=2); table_sig.autofit = False
cell_left = table_sig.rows[0].cells[0] ; cell_right = table_sig.rows[0].cells[1]

cell_left.paragraphs[0].text = "Mengetahui,\nKepala SD Negeri 8 Banjar Anyar\n\n\n\n___________________________\nNIP. "
cell_right.paragraphs[0].text = "Banjar Anyar, Juli 2026\nGuru Mata Pelajaran PJOK,\n\n\n\nGede Ardy Putrawan, S.Pd.\nNIP. -"

doc3.save("3_Lampiran_Administrasi_Pelengkap_Kelas5_Tebal.docx")
files.download("3_Lampiran_Administrasi_Pelengkap_Kelas5_Tebal.docx")
print("Bagian 3 Selesai Direvisi & Terunduh!")
# Out:
# Bagian 3 Selesai Direvisi & Terunduh!
